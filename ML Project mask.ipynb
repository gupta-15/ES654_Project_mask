# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import (RandomForestClassifier,
                              AdaBoostClassifier)
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
Data_mask=pd.read_csv("C:\\Sem 6\\ML_Project\\project_dataset_mask_phase2.csv")
Data_mask=Data_mask.iloc[:75,2:]
Data_mask
Data_mask=Data_mask.sample(frac=1)

# %%
Data_mask
# Out:
#                1             2            3             4            5  \
# 56  3.260000e+18  6.853200e+15   475.318851  5.669528e+06 -1484.876415
# 41  1.750000e+18  2.030000e+16    86.155748  3.811514e+06  -952.634141
# 28  1.880000e+18  3.130000e+16    60.114737  3.746310e+06  -913.964628
# 64  5.010000e+17  7.946920e+15    63.092381  2.086309e+06  -522.065220
# 48  1.220000e+19  9.780000e+16   124.805651  1.043655e+07 -2502.664213
# ..           ...           ...          ...           ...          ...
# 18  4.930000e+18  4.557130e+15  1080.957090  6.279874e+06 -1694.053103
# 33  1.490000e+18  2.280000e+16    65.322415  3.559724e+06  -877.200553
# 67  4.950000e+18  5.509570e+15   899.126817  5.610766e+06 -1499.269207
# 43  1.280000e+19  5.150000e+16   247.627548  9.765649e+06 -2483.964917
# 30  1.640000e+18  2.010000e+16    81.561412  3.582184e+06  -888.711909
#
#            6             7             8           9        10            11  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(Data_mask.iloc[:,:12], Data_mask.iloc[:,12:], test_size=0.3, random_state=42)

# %%
y_test
# Out:
#     Label
# 48      2
# 52      3
# 23      1
# 56      3
# 51      3
# 19      1
# 37      2
# 31      2
# 8       1
# 1       1
# 66      3
# 11      1
# 57      3
# 3       1
# 15      1
# 4       1
# 42      2
# 53      3
# 44      2
# 70      3
# 2       1
# 10      1
# 5       1

# %%
a=ExtraTreesClassifier(n_estimators=50)

# %%
a.fit(X_train,y_train)
# Out:
# C:\Users\Admin\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# ExtraTreesClassifier(n_estimators=50)

# %%
b=a.score(X_test,y_test)
b
# Out:
# 0.9565217391304348

# %%
x=[]
y=[]
for i in range(10,1000,5):
    a=ExtraTreesClassifier(n_estimators=i)
    a.fit(X_train,y_train)
    b=a.score(X_test,y_test)
    y.append(b)
    x.append(i)
plt.figure()
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# C:\Users\Admin\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# C:\Users\Admin\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# C:\Users\Admin\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# ...

# %%
y[-1]
# Out:
# 0.9565217391304348
